# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pprint import (pprint as pp, pformat as pf)
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

import dmyplant2
dmyplant2.cred()
mp = dmyplant2.MyPlant(0)

# %%
def sfun(x):
    return (
        #("BMW" in str(x['IB Site Name'])) and 
        #("Landshut" in str(x['IB Site Name'])) and 
        ("Forsa Hartmoor" in str(x['IB Site Name'])) and 
        #(x['Engine Series'] == "6") and
        #(x['Engine Type'] == '624') and
        (x['OperationalCondition'] != 'Decommissioned'))
res = mp.search_installed_fleet(sfun)
res.T
# Out:
#                                                        0   \
# index                                               26648
# Count_OpHour                                        164.0
# OperationalCondition                            Available
# startup_counter                                     117.0
# shutdown_counter                                    117.0
# id                                                 159396
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-10
# Design Number                                        AL87
# serialNumber                                      1486144
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                     0.87
# Control System Type                                   XT4
# Engine ID                                             M01
# IB Unit Commissioning Date                     2022-01-10
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL87
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-10
# Contract.Warranty Start Date                   2022-01-11
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        1   \
# index                                               26649
# Count_OpHour                                        161.0
# OperationalCondition                            Available
# startup_counter                                      93.0
# shutdown_counter                                     95.0
# id                                                 159397
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-10
# Design Number                                        AL87
# serialNumber                                      1486152
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                    0.792
# Control System Type                                   XT4
# Engine ID                                             M02
# IB Unit Commissioning Date                     2022-01-10
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL87
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-10
# Contract.Warranty Start Date                   2022-01-11
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        2   \
# index                                               26650
# Count_OpHour                                        142.0
# OperationalCondition                            Available
# startup_counter                                      93.0
# shutdown_counter                                     93.0
# id                                                 159398
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-11
# Design Number                                        AL88
# serialNumber                                      1486174
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                    0.857
# Control System Type                                   XT4
# Engine ID                                             M04
# IB Unit Commissioning Date                     2022-01-11
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL88
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-10
# Contract.Warranty Start Date                   2022-01-11
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        3   \
# index                                               26651
# Count_OpHour                                        149.0
# OperationalCondition                            Available
# startup_counter                                      91.0
# shutdown_counter                                     91.0
# id                                                 159399
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-11
# Design Number                                        AL88
# serialNumber                                      1486176
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                    0.714
# Control System Type                                   XT4
# Engine ID                                             M03
# IB Unit Commissioning Date                     2022-01-11
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL88
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-10
# Contract.Warranty Start Date                   2022-01-11
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        4   \
# index                                               26652
# Count_OpHour                                        157.0
# OperationalCondition                            Available
# startup_counter                                      89.0
# shutdown_counter                                     90.0
# id                                                 159400
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-22
# Design Number                                        AL89
# serialNumber                                      1486197
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                    0.721
# Control System Type                                   XT4
# Engine ID                                             M05
# IB Unit Commissioning Date                     2022-01-22
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL89
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-21
# Contract.Warranty Start Date                   2022-01-22
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        5   \
# index                                               26653
# Count_OpHour                                        162.0
# OperationalCondition                            Available
# startup_counter                                      88.0
# shutdown_counter                                     90.0
# id                                                 159401
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-10
# Design Number                                        AL89
# serialNumber                                      1486198
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                    0.706
# Control System Type                                   XT4
# Engine ID                                             M06
# IB Unit Commissioning Date                     2022-01-10
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL89
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-10
# Contract.Warranty Start Date                   2022-01-11
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        6   \
# index                                               26654
# Count_OpHour                                        155.0
# OperationalCondition                            Available
# startup_counter                                      82.0
# shutdown_counter                                     82.0
# id                                                 159402
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-11
# Design Number                                        AL90
# serialNumber                                      1486225
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                     0.66
# Control System Type                                   XT4
# Engine ID                                             M08
# IB Unit Commissioning Date                     2022-01-11
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL90
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-10
# Contract.Warranty Start Date                   2022-01-11
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        7   \
# index                                               26655
# Count_OpHour                                        147.0
# OperationalCondition                            Available
# startup_counter                                      85.0
# shutdown_counter                                     85.0
# id                                                 159403
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-11
# Design Number                                        AL90
# serialNumber                                      1486236
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                    0.745
# Control System Type                                   XT4
# Engine ID                                             M07
# IB Unit Commissioning Date                     2022-01-11
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL90
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-10
# Contract.Warranty Start Date                   2022-01-11
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        8   \
# index                                               26656
# Count_OpHour                                        134.0
# OperationalCondition                            Available
# startup_counter                                      84.0
# shutdown_counter                                     84.0
# id                                                 159404
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-11
# Design Number                                        AL91
# serialNumber                                      1486251
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                      1.0
# Control System Type                                   XT4
# Engine ID                                             M09
# IB Unit Commissioning Date                     2022-01-11
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL91
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-10
# Contract.Warranty Start Date                   2022-01-11
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        9   \
# index                                               26657
# Count_OpHour                                         97.0
# OperationalCondition                            Available
# startup_counter                                      74.0
# shutdown_counter                                     76.0
# id                                                 159405
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-22
# Design Number                                        AL91
# serialNumber                                      1486255
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                    1.082
# Control System Type                                   XT4
# Engine ID                                             M10
# IB Unit Commissioning Date                     2022-01-22
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL91
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-21
# Contract.Warranty Start Date                   2022-01-22
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020
#
#                                                        10
# index                                               26658
# Count_OpHour                                        133.0
# OperationalCondition                            Available
# startup_counter                                      82.0
# shutdown_counter                                     87.0
# id                                                 159406
# Engine Version                                        H12
# Engine Type                                           624
# Engine Series                                           6
# Country                                                GB
# Commissioning Date                             2022-01-11
# Design Number                                        AL92
# serialNumber                                      1486272
# Power_PowerNominal                                 4495.0
# Para_Speed_Nominal                                 1500.0
# starts_oph_ratio                                    0.864
# Control System Type                                   XT4
# Engine ID                                             M11
# IB Unit Commissioning Date                     2022-01-11
# IB NOX                                         250 mg/Nm3
# IB Frequency                                           50
# IB Item Description Engine    ENG JMS 624 H312 50__J_AL92
# IB Site Name                               Forsa Hartmoor
# IB Status                          Active Docu incomplete
# Contract.Warranty End Date                     2024-07-10
# Contract.Warranty Start Date                   2022-01-11
# Module_Vers_HalIO                              4.10.2.2.0
# Product Program                                      2020

# %%
res = res.sort_values(by = "Engine ID",ascending=True)
dval = mp.def_from_installed_fleet(res)
dval.T
# Out:
# Load Engine Data from MyPlant:: 100%|█████████████████████████████████████████████| 11/11 [00:16<00:00,  1.49s/ engines]
#                                     0                    1   \
# n                                    0                    1
# Validation Engine   Forsa Hartmoor M01   Forsa Hartmoor M02
# serialNumber                   1486144              1486152
# val start          2022-01-10 00:00:00  2022-01-10 00:00:00
# oph@start                           63                   54
# starts@start                        74                   57
# Asset ID                      159396.0             159397.0
#
#                                     2                    3   \
# n                                    3                    2
# Validation Engine   Forsa Hartmoor M03   Forsa Hartmoor M04
# serialNumber                   1486176              1486174
# val start          2022-01-11 00:00:00  2022-01-11 00:00:00
# oph@start                           51                   44
# starts@start                        52                   61
# Asset ID                      159399.0             159398.0
#
#                                     4                    5   \
# n                                    4                    5
# Validation Engine   Forsa Hartmoor M05   Forsa Hartmoor M06
# serialNumber                   1486197              1486198
# val start          2022-01-22 00:00:00  2022-01-10 00:00:00
# oph@start                          110                   57
# starts@start                        82                   48
# Asset ID                      159400.0             159401.0
#
#                                     6                    7   \
# n                                    7                    6
# Validation Engine   Forsa Hartmoor M07   Forsa Hartmoor M08
# serialNumber                   1486236              1486225
# val start          2022-01-11 00:00:00  2022-01-11 00:00:00
# oph@start                           45                   52
# starts@start                        50                   44
# Asset ID                      159403.0             159402.0
#
#                                     8                    9   \
# n                                    8                    9
# Validation Engine   Forsa Hartmoor M09   Forsa Hartmoor M10
# serialNumber                   1486251              1486255
# val start          2022-01-11 00:00:00  2022-01-22 00:00:00
# oph@start                           35                   84
# starts@start                        71                   84
# Asset ID                      159404.0             159405.0
#
#                                     10
# n                                   10
# Validation Engine   Forsa Hartmoor M11
# serialNumber                   1486272
# val start          2022-01-11 00:00:00
# oph@start                           37
# starts@start                        55
# Asset ID                      159406.0

# %%
vl = dmyplant2.Validation(mp, dval)
vl.dashboard
# Out:
# 55it [00:07,  6.93it/s]
#                   Name Engine ID Design Number Engine Type Engine Version   P  \
# 0   Forsa Hartmoor M01       M01          AL87         624            H12  24
# 1   Forsa Hartmoor M02       M02          AL87         624            H12  24
# 2   Forsa Hartmoor M03       M03          AL88         624            H12  24
# 3   Forsa Hartmoor M04       M04          AL88         624            H12  24
# 4   Forsa Hartmoor M05       M05          AL89         624            H12  24
# 5   Forsa Hartmoor M06       M06          AL89         624            H12  24
# 6   Forsa Hartmoor M07       M07          AL90         624            H12  24
# 7   Forsa Hartmoor M08       M08          AL90         624            H12  24
# 8   Forsa Hartmoor M09       M09          AL91         624            H12  24
# 9   Forsa Hartmoor M10       M10          AL91         624            H12  24
# 10  Forsa Hartmoor M11       M11          AL92         624            H12  24
#
#      P_nom  BMEP serialNumber      id  Count_OpHour  val start  oph@start  \
# 0   4582.1  24.5      1486144  159396         164.0 2022-01-10         63
# 1   4582.1  24.5      1486152  159397         161.0 2022-01-10         54
# 2   4582.1  24.5      1486176  159399         149.0 2022-01-11         51
# 3   4582.1  24.5      1486174  159398         142.0 2022-01-11         44
# 4   4582.1  24.5      1486197  159400         157.0 2022-01-22        110
# 5   4582.1  24.5      1486198  159401         162.0 2022-01-10         57
# 6   4582.1  24.5      1486236  159403         147.0 2022-01-11         45
# 7   4582.1  24.5      1486225  159402         155.0 2022-01-11         52
# 8   4582.1  24.5      1486251  159404         134.0 2022-01-11         35
# 9   4582.1  24.5      1486255  159405          97.0 2022-01-22         84
# 10  4582.1  24.5      1486272  159406         133.0 2022-01-11         37
#
#     oph parts       LOC
# 0         101  0.141000
# 1         107  0.119000
# 2          98  0.110000
# 3          98  0.076437
# 4          47  0.132500
# 5         105  0.169500
# 6         102  0.138889
# 7         103  0.126000
# 8          99  0.202500
# 9          13  0.192364
# 10         96  0.160937

# %%
from dfsm import msgFSM
fsm_data = []

for i, e in enumerate(vl.engines):
    print(f"\nEngine: {e}:")
    #lfsm = msgFSM(e, skip_days=7)
    lfsm = msgFSM(e, p_from=e['val start'])
    lfsm.run()
    fsm_data.append({'engine':e, 'fsm':lfsm})
# Out:
# Engine: 1486144 M01 Forsa Hartmoor M01     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|████████████████████████████████████████████████████| 13563/13563 [00:01<00:00, 10203.47 messages/s]
# Engine: 1486152 M02 Forsa Hartmoor M02     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|████████████████████████████████████████████████████| 10607/10607 [00:00<00:00, 12565.59 messages/s]
# Engine: 1486176 M03 Forsa Hartmoor M03     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|██████████████████████████████████████████████████████| 9741/9741 [00:00<00:00, 13764.59 messages/s]
# Engine: 1486174 M04 Forsa Hartmoor M04     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|████████████████████████████████████████████████████| 10678/10678 [00:00<00:00, 14262.82 messages/s]
# Engine: 1486197 M05 Forsa Hartmoor M05     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|████████████████████████████████████████████████████| 10330/10330 [00:00<00:00, 13874.23 messages/s]
# Engine: 1486198 M06 Forsa Hartmoor M06     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|██████████████████████████████████████████████████████| 9404/9404 [00:00<00:00, 13873.09 messages/s]
# Engine: 1486236 M07 Forsa Hartmoor M07     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|██████████████████████████████████████████████████████| 8236/8236 [00:00<00:00, 13144.58 messages/s]
# Engine: 1486225 M08 Forsa Hartmoor M08     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|██████████████████████████████████████████████████████| 7890/7890 [00:00<00:00, 13526.69 messages/s]
# Engine: 1486251 M09 Forsa Hartmoor M09     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|████████████████████████████████████████████████████| 11874/11874 [00:01<00:00, 11242.62 messages/s]
# Engine: 1486255 M10 Forsa Hartmoor M10     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|██████████████████████████████████████████████████████| 5848/5848 [00:00<00:00, 11080.29 messages/s]
# Engine: 1486272 M11 Forsa Hartmoor M11     :
# Message - '9047 target load reached' found.
# Scan Messages: 100%|██████████████████████████████████████████████████████| 6405/6405 [00:00<00:00, 12947.61 messages/s]

# %%
for res in fsm_data:
    rdf = pd.DataFrame(res['fsm']._starts)
    rda = rdf
    #rda = rdf[((rdf['mode'] == 'AUTO') & (rdf['success'] == True))]
    #rda = rdf[((rdf['mode'] == 'AUTO') & (rdf['success'] == True) & (rdf['synchronize'] < 300.0) & (rdf['startpreparation'] < 300.0))]
    #rda = rdf[((rdf['success'] == True) & (rdf['startpreparation'] < 1000.0))]
    rda = rdf[((rdf['success'] == True))]
    rda = rda[['success','mode','cumstarttime','startpreparation','starter','hochlauf','idle','synchronize','loadramp','targetoperation']]
    res['result'] = rdf
    res['filtered_result'] = rda

# %%
for res in fsm_data:
    print(f"""
*****************************************
** {str(res['engine'])} **
*****************************************""")
    print(f"{'Meldung':9} '{'9047 target load reached'}' {'gefunden.' if any(res['fsm']._messages['name'] == '9047') else 'wird berechnet.'}")
    print(f"{'Zeitraum':9}: {res['fsm'].first_message:%d.%m.%Y} bis {res['fsm'].last_message:%d.%m.%Y}")
    print(f"{'Dauer':9}: {res['fsm'].period.days:5} Tage")
    print(f"{'GESAMT':9}: {res['result'].shape[0]:5} Starts, {res['result'][res['result'].success].shape[0]:5} erfolgreich => {(res['result'][res['result'].success].shape[0] / res['result'].shape[0]) * 100.0:3.1f} % der Starts erfolgreich.")
    for mode in ['OFF','MANUAL', 'AUTO']:
        lstarts = res['result'][res['result']['mode'] == mode].shape[0]
        successful_starts = res['result'][((res['result'].success) & (res['result']['mode'] == mode))].shape[0]
        print(f"{mode:9}: {lstarts:5} Starts, {successful_starts:5} erfolgreich => {(successful_starts / lstarts) * 100.0 if lstarts != 0 else 0.0:3.1f} % der Starts erfolgreich.")
    #res['filtered_result'][['startpreparation','starter','hochlauf','idle','synchronize','cumstarttime','loadramp','targetoperation']].hist(figsize = (20,12), bins=50, layout=(3,3));
# Out:
# *****************************************
# ** 1486144 M01 Forsa Hartmoor M01      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 03.11.2021 bis 20.02.2022
# Dauer    :   116 Tage
# GESAMT   :   205 Starts,    77 erfolgreich => 37.6 % der Starts erfolgreich.
# OFF      :    11 Starts,     1 erfolgreich => 9.1 % der Starts erfolgreich.
# MANUAL   :    92 Starts,     3 erfolgreich => 3.3 % der Starts erfolgreich.
# AUTO     :   102 Starts,    73 erfolgreich => 71.6 % der Starts erfolgreich.
#
# *****************************************
# ** 1486152 M02 Forsa Hartmoor M02      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 05.11.2021 bis 20.02.2022
# Dauer    :   114 Tage
# GESAMT   :   160 Starts,    78 erfolgreich => 48.8 % der Starts erfolgreich.
# OFF      :     4 Starts,     1 erfolgreich => 25.0 % der Starts erfolgreich.
# MANUAL   :    52 Starts,     1 erfolgreich => 1.9 % der Starts erfolgreich.
# AUTO     :   104 Starts,    76 erfolgreich => 73.1 % der Starts erfolgreich.
#
# *****************************************
# ** 1486176 M03 Forsa Hartmoor M03      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 09.11.2021 bis 20.02.2022
# Dauer    :   110 Tage
# GESAMT   :   125 Starts,    73 erfolgreich => 58.4 % der Starts erfolgreich.
# OFF      :     5 Starts,     4 erfolgreich => 80.0 % der Starts erfolgreich.
# MANUAL   :    39 Starts,     2 erfolgreich => 5.1 % der Starts erfolgreich.
# AUTO     :    81 Starts,    67 erfolgreich => 82.7 % der Starts erfolgreich.
#
# *****************************************
# ** 1486174 M04 Forsa Hartmoor M04      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 22.06.2021 bis 20.02.2022
# Dauer    :   250 Tage
# GESAMT   :   135 Starts,    75 erfolgreich => 55.6 % der Starts erfolgreich.
# OFF      :     4 Starts,     3 erfolgreich => 75.0 % der Starts erfolgreich.
# MANUAL   :    35 Starts,     0 erfolgreich => 0.0 % der Starts erfolgreich.
# AUTO     :    96 Starts,    72 erfolgreich => 75.0 % der Starts erfolgreich.
#
# *****************************************
# ** 1486197 M05 Forsa Hartmoor M05      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 09.11.2021 bis 20.02.2022
# Dauer    :   110 Tage
# GESAMT   :   142 Starts,    79 erfolgreich => 55.6 % der Starts erfolgreich.
# OFF      :     0 Starts,     0 erfolgreich => 0.0 % der Starts erfolgreich.
# MANUAL   :    40 Starts,     1 erfolgreich => 2.5 % der Starts erfolgreich.
# AUTO     :   102 Starts,    78 erfolgreich => 76.5 % der Starts erfolgreich.
#
# *****************************************
# ** 1486198 M06 Forsa Hartmoor M06      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 10.11.2021 bis 20.02.2022
# Dauer    :   109 Tage
# GESAMT   :   131 Starts,    77 erfolgreich => 58.8 % der Starts erfolgreich.
# OFF      :     4 Starts,     2 erfolgreich => 50.0 % der Starts erfolgreich.
# MANUAL   :    30 Starts,     4 erfolgreich => 13.3 % der Starts erfolgreich.
# AUTO     :    97 Starts,    71 erfolgreich => 73.2 % der Starts erfolgreich.
#
# *****************************************
# ** 1486236 M07 Forsa Hartmoor M07      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 16.11.2021 bis 20.02.2022
# Dauer    :   103 Tage
# GESAMT   :   119 Starts,    71 erfolgreich => 59.7 % der Starts erfolgreich.
# OFF      :     4 Starts,     1 erfolgreich => 25.0 % der Starts erfolgreich.
# MANUAL   :    25 Starts,     1 erfolgreich => 4.0 % der Starts erfolgreich.
# AUTO     :    90 Starts,    69 erfolgreich => 76.7 % der Starts erfolgreich.
#
# *****************************************
# ** 1486225 M08 Forsa Hartmoor M08      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 17.11.2021 bis 20.02.2022
# Dauer    :   102 Tage
# GESAMT   :   105 Starts,    69 erfolgreich => 65.7 % der Starts erfolgreich.
# OFF      :     2 Starts,     0 erfolgreich => 0.0 % der Starts erfolgreich.
# MANUAL   :    22 Starts,     0 erfolgreich => 0.0 % der Starts erfolgreich.
# AUTO     :    80 Starts,    69 erfolgreich => 86.2 % der Starts erfolgreich.
#
# *****************************************
# ** 1486251 M09 Forsa Hartmoor M09      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 02.07.2021 bis 20.02.2022
# Dauer    :   240 Tage
# GESAMT   :   154 Starts,    73 erfolgreich => 47.4 % der Starts erfolgreich.
# OFF      :     3 Starts,     2 erfolgreich => 66.7 % der Starts erfolgreich.
# MANUAL   :    67 Starts,     0 erfolgreich => 0.0 % der Starts erfolgreich.
# AUTO     :    84 Starts,    71 erfolgreich => 84.5 % der Starts erfolgreich.
#
# *****************************************
# ** 1486255 M10 Forsa Hartmoor M10      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 25.11.2021 bis 20.02.2022
# Dauer    :    94 Tage
# GESAMT   :    83 Starts,    42 erfolgreich => 50.6 % der Starts erfolgreich.
# OFF      :     3 Starts,     1 erfolgreich => 33.3 % der Starts erfolgreich.
# MANUAL   :    23 Starts,     0 erfolgreich => 0.0 % der Starts erfolgreich.
# AUTO     :    56 Starts,    40 erfolgreich => 71.4 % der Starts erfolgreich.
#
# *****************************************
# ** 1486272 M11 Forsa Hartmoor M11      **
# *****************************************
# Meldung   '9047 target load reached' gefunden.
# Zeitraum : 02.12.2021 bis 20.02.2022
# Dauer    :    87 Tage
# GESAMT   :    82 Starts,    61 erfolgreich => 74.4 % der Starts erfolgreich.
# OFF      :     1 Starts,     0 erfolgreich => 0.0 % der Starts erfolgreich.
# MANUAL   :     8 Starts,     0 erfolgreich => 0.0 % der Starts erfolgreich.
# AUTO     :    73 Starts,    61 erfolgreich => 83.6 % der Starts erfolgreich.

# %%
rdb = rda[rdf['cumstarttime'] > 300.0]
rdb.round(2)
# Out:
#     success  mode  cumstarttime  startpreparation  starter  hochlauf  idle  \
# 3      True  AUTO        356.61             168.84     3.73     25.56  5.96
# 8      True  AUTO        308.84             168.98     3.94      7.87  6.27
# 35     True  AUTO        461.22             256.80     4.14     20.18  5.75
# 42     True  AUTO        455.66             257.99     3.73     23.90  6.27
#
#     synchronize  loadramp targetoperation
# 3         27.13     125.39  0 days 02:15:32
# 8         50.74      71.04  0 days 00:06:54
# 35        48.83     125.52  0 days 00:13:27
# 42        38.65     125.12  0 days 00:17:59

# %%
rdb.describe().round(2).T
# Out:
#                   count             mean                        std  \
# cumstarttime        4.0           395.58                      75.19
# startpreparation   4.0           213.15                      51.09
# starter             4.0             3.88                       0.19
# hochlauf            4.0            19.38                       7.99
# idle                4.0             6.06                       0.25
# synchronize         4.0            41.34                      10.86
# loadramp           4.0           111.77                      27.15
# targetoperation      4  0 days 00:43:28  0 days 01:01:32.770143582
#
#                                min                     25%              50%  \
# cumstarttime                308.84                  344.67           406.13
# startpreparation           168.84                  168.95           212.89
# starter                       3.73                    3.73             3.83
# hochlauf                      7.87                    17.1            22.04
# idle                          5.75                    5.91             6.11
# synchronize                  27.13                   35.77            43.74
# loadramp                    71.04                   111.6           125.25
# targetoperation   0 days 00:06:54  0 days 00:11:48.750000  0 days 00:15:43
#
#                                       75%              max
# cumstarttime                       457.05           461.22
# startpreparation                   257.1           257.99
# starter                              3.99             4.14
# hochlauf                            24.31            25.56
# idle                                 6.27             6.27
# synchronize                          49.3            50.74
# loadramp                          125.43           125.52
# targetoperation   0 days 00:47:22.250000  0 days 02:15:32

# %%
rdc = rda[rdf['loadramp'] < 120.0]
rdc.round(2)
# Out:
#     success  mode  cumstarttime  startpreparation  starter  hochlauf  idle  \
# 8      True  AUTO        308.84             168.98     3.94      7.87  6.27
# 10     True  AUTO        197.35              60.75     4.44     18.97  5.34
# 76     True  AUTO        277.02             139.37     3.53     19.77  5.05
#
#     synchronize  loadramp targetoperation
# 8         50.74      71.04  0 days 00:06:54
# 10        36.48      71.37  0 days 00:02:14
# 76         3.63     105.67  0 days 00:30:51

# %%
rdc.describe().round(2).T

# %%
print("""
****************
** Überblick: **
****************
""")
print(f"{'Motor':9}: {e}")
print(f"{'Meldung':9}- '{'9047 target load reached'}' {'gefunden.' if any(fsm._messages['name'] == '9047') else 'wird berechnet.'}")
print(f"{'Zeitraum':9}: {fsm.first_message:%d.%m.%Y} bis {fsm.last_message:%d.%m.%Y}")
print(f"{'Dauer':9}: {fsm.period.days} Tage")
print()
print(f"{'GESAMT':9}: {rdf.shape[0]:5} Starts, {rdf[rdf.success].shape[0]:5} erfolgreich => {(rdf[rdf.success].shape[0] / rdf.shape[0]) * 100.0:3.1f} % der Starts erfolgreich.")
for mode in ['MANUAL', 'AUTO']:
    print(f"{mode:9}: {rdf[(rdf['mode'] == mode)].shape[0]:5} Starts, {rdf[((rdf.success) & (rdf['mode'] == mode))].shape[0]:5} erfolgreich => {(rdf[((rdf.success) & (rdf['mode'] == mode))].shape[0] / rdf[(rdf['mode'] == mode)].shape[0]) * 100.0:3.1f} % der Starts erfolgreich.")

# %%
rda.describe().round(2).T

# %%
rda[['startpreparation','starter','hochlauf','idle','synchronize','cumstarttime','loadramp','targetoperation']].hist(figsize = (20,12), bins=50, layout=(3,3));
#rda.hist(figsize = (20,12), bins=100, layout=(4,2));

# %%
rda.plot.box(subplots=True, grid = True, figsize=(24,10), layout=(1,7));

# %%
rda.plot.box(subplots=True, grid = True, figsize=(24,10), layout=(1,7), sym='');

# %%
nalarms = []
ct = 0
for i,c in rdf.iterrows():
    if len(c['alarms']) > 0 and not c['success']:
        ct += 1
        print(f"\nStartversuch: {i}, Success: {c['success']}")
        for a in c['alarms']:
            nalarms.append(a['msg'])
            print(f"{c['mode']:15} {a['state']:20} {pd.to_datetime(int(a['msg']['timestamp'])*1e6).strftime('%d.%m.%Y %H:%M:%S')} {a['msg']['name']} {a['msg']['message']}")
print(f"""
***********************************
** {ct:3} nicht erfolgreiche Starts **
***********************************
""")

# %%
al = pd.DataFrame(fsm._pareto(nalarms))
fig = plt.figure();
color = 'purple'

if not al.empty:
    al['msg'] = al['msg'] + ' (' + al['name'] + ')'
    al.set_index('msg').sort_values(by = "anz",ascending=True).plot.barh(y=['anz'],figsize=(16,len(al) / 3.8), color=[color], position = 1.0, grid=True, title='Alarms in not successful Starts');
    plt.plot();

# %%
phases = [['startpreparation','starter','hochlauf','idle','synchronize','loadramp','targetoperation'],'startpreparation','starter','hochlauf','idle','synchronize','loadramp','targetoperation']
fig = plt.figure();
color = 'red'

for phase in phases:
    al = fsm.alarms_pareto(phase)[:20]
    if not al.empty:
        al['msg'] = al['msg'] + ' (' + al['name'] + ')'
        al.set_index('msg').sort_values(by = "anz",ascending=True).plot.barh(y=['anz'],figsize=(16,len(al) / 3.8), color=[color], position = 1.0, grid=True, title=' | '.join(phase) if type(phase) == list else phase);
        plt.plot();

# %%
phases = [['startpreparation','starter','hochlauf','idle','synchronize','loadramp','targetoperation'],'startpreparation','starter','hochlauf','idle','synchronize','loadramp','targetoperation']
fig = plt.figure();
color = 'orange'

for phase in phases:
    al = fsm.warnings_pareto(phase)[:20]
    if not al.empty:
        al['msg'] = al['msg'] + ' (' + al['name'] + ')'
        al.set_index('msg').sort_values(by = "anz",ascending=True).plot.barh(y=['anz'],figsize=(16,len(al) / 3.8), color=[color], position = 1.0, grid=True, title=' | '.join(phase) if type(phase) == list else phase);
        plt.plot();

# %%
mfn = './data/' + str(e._sn) + '_messages.txt'
fsm.save_messages('./data/' + str(e._sn) + '_messages.txt')
print(mfn)

# %%
any(fsm._messages['name'] == '9047')

# %%
#fsm.store()
