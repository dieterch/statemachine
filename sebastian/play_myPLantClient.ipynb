# %%
# %reload_ext autoreload
# %aimport -pandas, -numpy
# %autoreload 2
import pandas as pd
import numpy as np
from myPlant_Client_giovanni import myPlant_Client

# %%
client = myPlant_Client()

# %%
client.get_access_token()

# %%
assets = client.get_assets()

# %%
assets
# Out:
#        assetId serialNumber                   customer_name  \
# 0            1         C875     P VAN DER HOEVEN ELECTRO BV
# 1            3         C105              JAM GROENEWEGEN BV
# 2            4         E018          Kwekerij T Varekamp BV
# 3            5      4054171                   SO Natural BV
# 4            7      4332781              JAM GROENEWEGEN BV
# ...        ...          ...                             ...
# 74281   175683        Gen E  United Energy Pakistan Limited
# 74282   175690       AX1701                             NaN
# 74283   175693      1658584            Default Organization
# 74284   175694      1658501            Default Organization
# 74285   175695      1658499            Default Organization
#
#                site_name Customer Engine Number     site_country Engine Type  \
# 0      Zwinkels Kwekerij                    NaN               NL         NaN
# 1      Groenewegen, J.A.                    NaN               NL         NaN
# 2             Varekamp 3                    NaN               NL         NaN
# 3                Smaal 1                    OLD               NL         612
# 4      Groenewegen, J.A.                      1               NL         620
# ...                  ...                    ...              ...         ...
# 74281            Phase-V                  Gen E         Pakistan         NaN
# 74282                NaN                    NaN              NaN         NaN
# 74283       Default Site                    NaN  Default Country         NaN
# 74284       Default Site                    NaN  Default Country         NaN
# 74285       Default Site                    NaN  Default Country         NaN
#
#       OperationalCondition               model  modelId  ...  Count_Start  \
# 0                      NaN  GEJenbacherGateway       21  ...          NaN
# 1                      NaN  GEJenbacherGateway       21  ...          NaN
# 2                      NaN  GEJenbacherGateway       21  ...          NaN
# 3           Decommissioned            J-Engine       23  ...          0.0
# 4           Decommissioned            J-Engine       23  ...       9118.0
# ...                    ...                 ...      ...  ...          ...
# 74281              Unknown            W-Engine      570  ...          NaN
# 74282                  NaN  GEJenbacherGateway       21  ...          NaN
# 74283      Never Connected            J-Engine       23  ...          NaN
# 74284      Never Connected            J-Engine       23  ...          NaN
# 74285      Never Connected            J-Engine       23  ...          NaN
#
#        Issue_Eng_OpHour  Gas Type  Engine Version  Engine Series  \
# 0                   NaN       NaN             NaN            NaN
# 1                   NaN       NaN             NaN            NaN
# 2                   NaN       NaN             NaN            NaN
# 3                   0.0       NG1             E01              6
# 4                   0.0       NG1            E166              6
# ...                 ...       ...             ...            ...
# 74281               NaN       NaN             NaN            NaN
# 74282               NaN       NaN             NaN            NaN
# 74283               NaN       NaN             NaN            NaN
# 74284               NaN       NaN             NaN            NaN
# 74285               NaN       NaN             NaN            NaN
#
#       Commissioning Date Design Number Power_PowerNominal  \
# 0                    NaN           NaN                NaN
# 1                    NaN           NaN                NaN
# 2                    NaN           NaN                NaN
# 3             2004-08-13          B627                NaN
# 4             2005-12-16          C105             3045.0
# ...                  ...           ...                ...
# 74281                NaN           NaN                NaN
# 74282                NaN           NaN                NaN
# 74283                NaN          BH24                NaN
# 74284                NaN          BH12                NaN
# 74285                NaN          BH12                NaN
#
#       Contract.Service Contract Type Para_Engine_Power_FastStart_GEN2_preM_Act
# 0                                NaN                                       NaN
# 1                                NaN                                       NaN
# 2                                NaN                                       NaN
# 3                                NaN                                       NaN
# 4          PREVENTIVE AND CORRECTIVE                                       NaN
# ...                              ...                                       ...
# 74281                            NaN                                       NaN
# 74282                            NaN                                       NaN
# 74283                            NaN                                       NaN
# 74284                            NaN                                       NaN
# 74285                            NaN                                       NaN
#
# [74286 rows x 23 columns]

# %%
properties = client.get_properties()

# %%
dataItems = client.get_dataItems()

# %%
dataItems['modelId'].unique()
# Out:
# array([ 690,  590,  570,   21,   23,  990, 1371, 1015, 1030, 1450,  871,
#        1230,  387,  950,  631, 1017, 1019, 1011,  894,  930,  970, 1014,
#         933, 1430,  931,  630, 1018,  550, 1350, 1016, 1136, 1137, 1134,
#        1132, 1411, 1135, 1012,  934,  127,  932, 1291, 1133,   24, 1131,
#         105,    1,  489, 1130,  610, 1138, 1139, 1270, 1090, 1410, 1170,
#        1370,   84, 1290, 1250,  850, 1050, 1210,  670,  910])

# %%
myassets = client._request_assets(limit=2)
myassets.json()
# Out:
# {'data': {'assets': {'items': [{'geoLocation': None,
#      'serialNumber': 'C875',
#      'dataItems': [],
#      'model': 'GEJenbacherGateway',
#      'site': {'name': 'Zwinkels Kwekerij', 'country': 'NL'},
#      'modelId': 21,
#      'id': 1,
#      'properties': [],
#      'customer': {'name': 'P VAN DER HOEVEN ELECTRO BV'}},
#     {'geoLocation': None,
#      'serialNumber': 'C105',
#      'dataItems': [],
#      'model': 'GEJenbacherGateway',
#      'site': {'name': 'Groenewegen, J.A.', 'country': 'NL'},
#      'modelId': 21,
#      'id': 3,
#      'properties': [],
#      'customer': {'name': 'JAM GROENEWEGEN BV'}}]}}}
