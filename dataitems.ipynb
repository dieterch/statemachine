# %%
import dmyplant2
from dmyplant2 import MyPlant as mp
d = dmyplant2.MyPlant.get_dataitems()

# %%
d;

# %%
def sfun(x):
    return \
    (("Exhaust_Temp".upper() in str(x['name']).upper()) and 
     #("temp".upper() in str(x['name']).upper()) and 
     not str(x['name']).startswith('Para'))

d[d.apply(lambda x: sfun(x), axis=1)].sort_values(by = "name",ascending=True).reset_index(drop='index')
# Out:
#          id                     name      unit  \
# 0        59         Exhaust_TempBoil         C
# 1        61          Exhaust_TempCat         C
# 2        25        Exhaust_TempCatIn         C
# 3       189       Exhaust_TempCatOut         C
# 4        26        Exhaust_TempCyl01  C (high)
# 5        27        Exhaust_TempCyl02  C (high)
# 6        28        Exhaust_TempCyl03  C (high)
# 7        29        Exhaust_TempCyl04  C (high)
# 8        30        Exhaust_TempCyl05  C (high)
# 9        31        Exhaust_TempCyl06  C (high)
# 10       32        Exhaust_TempCyl07  C (high)
# 11       33        Exhaust_TempCyl08  C (high)
# 12       34        Exhaust_TempCyl09  C (high)
# 13       35        Exhaust_TempCyl10  C (high)
# 14       36        Exhaust_TempCyl11  C (high)
# 15       37        Exhaust_TempCyl12  C (high)
# 16       38        Exhaust_TempCyl13  C (high)
# 17       41        Exhaust_TempCyl14  C (high)
# 18       43        Exhaust_TempCyl15  C (high)
# 19       44        Exhaust_TempCyl16  C (high)
# 20       45        Exhaust_TempCyl17  C (high)
# 21       46        Exhaust_TempCyl18  C (high)
# 22       48        Exhaust_TempCyl19  C (high)
# 23       50        Exhaust_TempCyl20  C (high)
# 24      190        Exhaust_TempCyl21  C (high)
# 25      193        Exhaust_TempCyl22  C (high)
# 26      191        Exhaust_TempCyl23  C (high)
# 27      194        Exhaust_TempCyl24  C (high)
# 28       52       Exhaust_TempCylAvg  C (high)
# 29  1000048    Exhaust_TempCylAvg_ss         C
# 30       63       Exhaust_TempCylMax  C (high)
# 31  1000050    Exhaust_TempCylMax_ss         C
# 32       54       Exhaust_TempCylMin  C (high)
# 33  1000049    Exhaust_TempCylMin_ss         C
# 34      214        Exhaust_TempETCIn  C (high)
# 35       56        Exhaust_TempHexIn  C (high)
# 36       65       Exhaust_TempHexOut  C (high)
# 37    19093  Exhaust_TempLPTCOutletA        °C
# 38    19094  Exhaust_TempLPTCOutletB        °C
# 39  1000051    Exhaust_TempMaxSpread         C
#
#                                          myPlantName
# 0                                 Boiler temperature
# 1                            Catalysator temperature
# 2                            Catalysator inlet temp.
# 3                           Catalysator outlet temp.
# 4                        Exhaust temperature cyl. 01
# 5                        Exhaust temperature cyl. 02
# 6                        Exhaust temperature cyl. 03
# 7                        Exhaust temperature cyl. 04
# 8                        Exhaust temperature cyl. 05
# 9                        Exhaust temperature cyl. 06
# 10                       Exhaust temperature cyl. 07
# 11                       Exhaust temperature cyl. 08
# 12                       Exhaust temperature cyl. 09
# 13                       Exhaust temperature cyl. 10
# 14                       Exhaust temperature cyl. 11
# 15                       Exhaust temperature cyl. 12
# 16                       Exhaust temperature cyl. 13
# 17                       Exhaust temperature cyl. 14
# 18                       Exhaust temperature cyl. 15
# 19                       Exhaust temperature cyl. 16
# 20                       Exhaust temperature cyl. 17
# 21                       Exhaust temperature cyl. 18
# 22                       Exhaust temperature cyl. 19
# 23                       Exhaust temperature cyl. 20
# 24                       Exhaust temperature cyl. 21
# 25                       Exhaust temperature cyl. 22
# 26                       Exhaust temperature cyl. 23
# 27                       Exhaust temperature cyl. 24
# 28                  Exhaust temperature cyl. average
# 29  Averaged Exhaust Gas Temperature in Operation
# 30                  Exhaust temperature cyl. maximum
# 31      Maximum Exhaust Gas Temperature in Operation
# 32                  Exhaust temperature cyl. minimum
# 33      Minimum Exhaust Gas Temperature in Operation
# 34                          Turbocharger inlet temp.
# 35                   Turbocharger outlet temperature
# 36                       Heat exchanger outlet temp.
# 37   Exhaust gas temperature after low pressure TC A
# 38   Exhaust gas temperature after low pressure TC B
# 39                    Exhaust Gas Temperature Spread

# %%
import pandas as pd
pd.options.mode.chained_assignment = None # default warn => SettingWithCopyWarning
import numpy as np
import matplotlib.pyplot as plt
import bokeh
from collections import namedtuple
from pprint import (pprint as pp, pformat as pf)
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)
from IPython.display import HTML, display
import ipywidgets as widgets
import arrow

import dmyplant2
dmyplant2.cred()
mp = dmyplant2.MyPlant(3600)

# %%
mp.get_dataitems()
# Out:
#             id                                               name unit  \
# 0        18180                    Para_Island_Limit_LSdSpeedLimit  NaN
# 1     10008855              Para_ModulControler_Ctr30_t_period_up  NaN
# 2           69                                   Hyd_PressCoolWat  bar
# 3     10000302                         Para_Gas_Pr_GasPrAbsActive  NaN
# 4      1019355                       RMD_BlowByFilterOPHEventLast  NaN
# ...        ...                                                ...  ...
# 5906  10050149                               safi_iu_safi_win4_20   mV
# 5907  10008551  Para_Hydraulic_Oil_OilFilterUnit_Pr_OFUaFilt_A...  NaN
# 5908  10049863                   auxiliariesgeneral_rpr_eo_diff_f  NaN
# 5909  10008419                    Para_ModulControler_Ctr27_dW_up  NaN
# 5910     17365                        Para_Exhaust_TempInTurboMax  NaN
#
#                                             myPlantName
# 0     Engine / Isolated operation / Limit / Speed li...
# 1     Plant controller / Outlet air fan - Room tempe...
# 2                                Cooling water pressure
# 3        Gas / Gas pressure measuring absolute  (11388)
# 4                          RMD BlowByFilterOPHEventLast
# ...                                                 ...
# 5906                  Inlet valve closure noise cyl. 20
# 5907  Hydraulic / Oil / Oil filter unit / Oil pressu...
# 5908                     Oil filter difference pressure
# 5909  Plant controller / Supply water temperature co...
# 5910  Exhaust / Turbocharger inlet temp. maximum (11...
#
# [5911 rows x 4 columns]
