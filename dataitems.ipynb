# %%
import arrow
from pprint import pprint as pp
import dmyplant2
from dmyplant2 import MyPlant
#erg = MyPlant.lookup_dataitems(lookup='alar',exclude='Para_')
erg = MyPlant.lookup_dataitems(lookup='cyl01',exclude='Para_')
#erg = MyPlant.lookup_dataitems(lookup='Hyd_',exclude='Para_')
erg
# Out:
#           id                                       name  unit  \
# 0      16591                          Ignition_ITPCyl01   °KW
# 1      19219                        PBC_PressMean_Cyl01   bar
# 2    1040010  valverecession_rev_cyl01_deltaVRSinceInit    mm
# 3    1040010  valverecession_rev_cyl01_deltaVRSinceInit    mm
# 4   10044516        manualdata_valverecession_lev_cyl01    mm
# 5   10044464        manualdata_valverecession_liv_cyl01    mm
# 6      19140                 Knock_PBC_KnockPress_Cyl01  mbar
# 7    1039914              valverecession_rev_cyl01_init    mm
# 8        133                 Knock_KLS98_IntKnock_Cyl01     %
# 9      19194                      PBC_HeatCharVar_Cyl01   °CA
# 10   1039866              valverecession_lev_cyl01_init    mm
# 11  10044325   manualdata_logbook_exhaust_gastemp_cyl01    °C
# 12   1040034  valverecession_riv_cyl01_deltaVRSinceInit    mm
# 13   1040034  valverecession_riv_cyl01_deltaVRSinceInit    mm
# 14   1039938              valverecession_riv_cyl01_init    mm
# 15     20399                   Combustion_Quality_Cyl01     %
# 16     20310                          PI_Duration_Cyl01   °CA
# 17   1039986  valverecession_liv_cyl01_deltaVRSinceInit    mm
# 18   1039986  valverecession_liv_cyl01_deltaVRSinceInit    mm
# 19   1039962  valverecession_lev_cyl01_deltaVRSinceInit    mm
# 20   1039962  valverecession_lev_cyl01_deltaVRSinceInit    mm
# 21  10008716                    Knock_Valve_Noise_Cyl01    mV
# 22   1039890              valverecession_liv_cyl01_init    mm
# 23        80                            Monic_VoltCyl01    kV
# 24     20351                     PBC_Press49bfTDC_Cyl01  mbar
# 25     20375               Combustion_Quality_Max_Cyl01     %
# 26     19167                       Knock_PBC_PMax_Cyl01   bar
# 27     16547                    Knock_KLS98_Knock_Cyl01    mV
# 28  10044540        manualdata_valverecession_riv_cyl01    mm
# 29        26                          Exhaust_TempCyl01    °C
# 30   1040058     valverecession_cyl01_deltaOphSinceInit   oph
# 31  10049003          valverecession_cyl01_new_cyl_head   NaN
# 32  10044564        manualdata_valverecession_rev_cyl01    mm
#
#                                           myPlantName
# 0                                         ITP cyl. 01
# 1                                             IMEP 01
# 2         Valve Recession - Cyl01 - Right Outlet Wear
# 3                    Cyl. 01 Valve Wear Right Exhaust
# 4   Valve Recession - Cyl01 - Left Outlet Measurement
# 5    Valve Recession - Cyl01 - Left Inlet Measurement
# 6                                     Knock signal 01
# 7   Valve Recession - Cyl01 - Right Outlet - Init ...
# 8                            Knock integrator cyl. 01
# 9                                               AI 01
# 10  Valve Recession - Cyl01 - Left Outlet - Init V...
# 11                  Logbook: Exhaust gas temp Cyl. 01
# 12         Valve Recession - Cyl01 - Right Inlet Wear
# 13                     Cyl. 01 Valve Wear Right Inlet
# 14  Valve Recession - Cyl01 - Right Inlet - Init V...
# 15                                               CQ 1
# 16                             Duration of opening 01
# 17          Valve Recession - Cyl01 - Left Inlet Wear
# 18                      Cyl. 01 Valve Wear Left Inlet
# 19         Valve Recession - Cyl01 - Left Outlet Wear
# 20                    Cyl. 01 Valve Wear Left Exhaust
# 21                           Mechanical noise cyl. 01
# 22  Valve Recession - Cyl01 - Left Inlet - Init Va...
# 23                           Ignition voltage cyl. 01
# 24                    Pressure 49° before TDC cyl. 01
# 25                                           CQ max 1
# 26                                           P-max 01
# 27                                Knock noise cyl. 01
# 28  Valve Recession - Cyl01 - Right Inlet Measurement
# 29                        Exhaust temperature cyl. 01
# 30      Valve Recession - Cyl01 - Cyl Head Age (Op.h)
# 31        Valve Recession - Cyl01 - New Cyl Head Flag
# 32  Valve Recession - Cyl01 - Right Outlet Measure...

# %%
dmyplant2.cred()
mp = dmyplant2.MyPlant(0)
e=dmyplant2.Engine.from_sn(mp,1486174)
print(e)
# Out:
# 1486174 Forsa Hartmoor M04

# %%
e.assess_dataItems(list(erg['name']), arrow.get('2022-01-14 16:23:06'))
# Out:
# ERROR:root:Code: /asset/159398/history/batchdata?from=1642177386000&to=1642177387000&timeCycle=1&assetType=J-Engine&includeMinMax=false&forceDownSampling=false&dataItemIds=, 404, No data was found
# ERROR:root:Code: /asset/159398/history/batchdata?from=1642177386000&to=1642177387000&timeCycle=1&assetType=J-Engine&includeMinMax=false&forceDownSampling=false&dataItemIds=, 404, No data was found
# [{'Ignition_ITPCyl01': True, 'value': 8.0},
#  {'PBC_PressMean_Cyl01': True, 'value': 0.0},
#  {'valverecession_rev_cyl01_deltaVRSinceInit': True, 'value': 0.0},
#  {'valverecession_rev_cyl01_deltaVRSinceInit': True, 'value': 0.0},
#  {'manualdata_valverecession_lev_cyl01': True, 'value': 7.68},
#  {'manualdata_valverecession_liv_cyl01': True, 'value': -0.19},
#  {'Knock_PBC_KnockPress_Cyl01': True, 'value': 0.0},
#  {'valverecession_rev_cyl01_init': True, 'value': 7.66},
#  {'Knock_KLS98_IntKnock_Cyl01': True, 'value': 0.0},
#  {'PBC_HeatCharVar_Cyl01': True, 'value': 0.0},
#  {'valverecession_lev_cyl01_init': True, 'value': 7.68},
#  {'manualdata_logbook_exhaust_gastemp_cyl01': True, 'value': -9999},
#  {'valverecession_riv_cyl01_deltaVRSinceInit': True, 'value': 0.0},
#  {'valverecession_riv_cyl01_deltaVRSinceInit': True, 'value': 0.0},
#  {'valverecession_riv_cyl01_init': True, 'value': -0.28},
#  {'Combustion_Quality_Cyl01': True, 'value': 0.0},
#  {'PI_Duration_Cyl01': True, 'value': 0.0},
#  {'valverecession_liv_cyl01_deltaVRSinceInit': True, 'value': 0.0},
#  {'valverecession_liv_cyl01_deltaVRSinceInit': True, 'value': 0.0},
#  {'valverecession_lev_cyl01_deltaVRSinceInit': True, 'value': 0.0},
#  {'valverecession_lev_cyl01_deltaVRSinceInit': True, 'value': 0.0},
#  {'Knock_Valve_Noise_Cyl01': True, 'value': 0.0},
#  {'valverecession_liv_cyl01_init': True, 'value': -0.19},
#  {'Monic_VoltCyl01': True, 'value': 0.0},
#  {'PBC_Press49bfTDC_Cyl01': True, 'value': 0.0},
#  {'Combustion_Quality_Max_Cyl01': True, 'value': 0.0},
#  {'Knock_PBC_PMax_Cyl01': True, 'value': 0.0},
#  {'Knock_KLS98_Knock_Cyl01': True, 'value': 0.0},
#  {'manualdata_valverecession_riv_cyl01': True, 'value': -0.28},
#  {'Exhaust_TempCyl01': True, 'value': 52.974},
#  {'valverecession_cyl01_deltaOphSinceInit': True, 'value': -9999},
#  {'valverecession_cyl01_new_cyl_head': True, 'value': 1.0},
#  {'manualdata_valverecession_rev_cyl01': True, 'value': 7.66}]
