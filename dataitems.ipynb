# %%
import arrow
from pprint import pprint as pp
import dmyplant2
from dmyplant2 import MyPlant
#erg = MyPlant.lookup_dataitems(lookup='alar',exclude='Para_')
erg = MyPlant.lookup_dataitems(lookup='Hyd_',exclude='Para_')
#erg = MyPlant.lookup_dataitems(lookup='Hyd_',exclude='Para_')
erg
# Out:
#        id                               name   unit  \
# 0      69                   Hyd_PressCoolWat    bar
# 1     217                 Hyd_PressCrankCase   mbar
# 2     185               Hyd_TempWatRetPreEng      C
# 3     228       Hyd_OilCount_Trend_OilVolume     ml
# 4      70                    Hyd_TempCoolWat      C
# 5     156              Hyd_TempWatRetCoolOut     °C
# 6   19302               Hyd_PressTCOilFiltIn    bar
# 7     225    Hyd_OilCount_Trend_ActiveEnergy    NaN
# 8     237        Hyd_OilCount_Trend_DeltaOpH    NaN
# 9   19303                 Hyd_TempOilPumpOut     °C
# 10     71                        Hyd_TempOil      C
# 11    226        Hyd_OilCount_Trend_AvgPower     kW
# 12     72                     Hyd_TempWatRet      C
# 13     68                       Hyd_PressOil    bar
# 14    227  Hyd_OilCount_Trend_OilConsumption  g/kWh
# 15  16546                    Hyd_PressOilDif    bar
#
#                                myPlantName
# 0                   Cooling water pressure
# 1                       Pressure crankcase
# 2         Return water temp. before engine
# 3                   Oil counter oil volume
# 4                Cooling water temperature
# 5   Return water temperature cooler outlet
# 6             Oil pressure TC filter inlet
# 7                Oil counter active energy
# 8      Oil counter operational hours delta
# 9              Oil temperature pump outlet
# 10                         Oil temperature
# 11               Oil counter power average
# 12                Return water temperature
# 13                            Oil pressure
# 14             Oil counter oil consumption
# 15                 Oil difference pressure

# %%
dmyplant2.cred()
mp = dmyplant2.MyPlant(0)
e=dmyplant2.Engine.from_sn(mp,1486174)
print(e)
# Out:
# 1486174 Forsa Hartmoor M04

# %%
e.assess_dataItems(list(erg['name']), arrow.get('2022-01-14 16:23:06'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hyd_TempOil'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/dieterchvatal/prog/python3/statemachine/dataitems.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/dieterchvatal/prog/python3/statemachine/dataitems.ipynb#ch0000003?line=0'>1</a> e.assess_dataItems(list(erg['name']), arrow.get('2022-01-14 16:23:06'))
#
# File ~/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py:563, in Engine.assess_dataItems(self, testset, p_ts)
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=552'>553</a> try:
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=553'>554</a>     testdata = self._mp.hist_data(
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=554'>555</a>         self.id,
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=555'>556</a>         itemIds= self._mp.get_itemIDs([item]),
#    (...)
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=558'>559</a>         timeCycle=1,
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=559'>560</a>         silent=True)
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=560'>561</a>     result.append({
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=561'>562</a>         item:True,
# --> <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=562'>563</a>         'value': testdata[item].iloc[0] if not testdata.empty else -9999,
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=563'>564</a>         })
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=564'>565</a> except ValueError as err:
#     <a href='file:///Users/dieterchvatal/Documents/Anaconda/dmyplant4/dmyplant2/dEngine.py?line=565'>566</a>     result.append({item:False})
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///Users/dieterchvatal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'Hyd_TempOil'
